# %% [markdown]
# <a href="https://colab.research.google.com/github/coffeeGhost-rj/pyCodeRep/blob/feature/example1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome RK")
# Out:
# welcome RK

# %%
a = input("name please: ")
print(a)
# Out:
# name please: hello f
# hello f
